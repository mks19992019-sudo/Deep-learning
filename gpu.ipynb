# %%
import tensorflow as tf

print(tf.config.list_physical_devices())
print(tf.config.list_physical_devices('GPU'))
# Out:
# [PhysicalDevice(name='/physical_device:CPU:0', device_type='CPU')]
# []

# %%
# Out:
#   Cell In[4], line 2
#     pip show tensorflow
#         ^
# SyntaxError: invalid syntax

# %%
import sys
print(sys.executable)
# Out:
# /Users/All file hear/complete ai /Deep learning/.venv/bin/python

# %%
import tensorflow as tf

print(tf.config.list_physical_devices('GPU'))
# Out:
# []

# %%
import tensorflow as tf

print(tf.config.list_physical_devices('GPU'))
# Out:
# []

# %%
import tensorflow as tf

print(tf.config.list_physical_devices('GPU'))
# Out:
# ---------------------------------------------------------------------------
# NotFoundError                             Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 import tensorflow as tf
#       2
#       3 print(tf.config.list_physical_devices('GPU'))
#
# File /Users/All file hear/complete ai /Deep learning/.venv/lib/python3.12/site-packages/tensorflow/__init__.py:439
#     437 _plugin_dir = _os.path.join(_s, "tensorflow-plugins")
#     438 if _os.path.exists(_plugin_dir):
# --> 439   _ll.load_library(_plugin_dir)
#     440   # Load Pluggable Device Library
#     441   _ll.load_pluggable_device_library(_plugin_dir)
#
# File /Users/All file hear/complete ai /Deep learning/.venv/lib/python3.12/site-packages/tensorflow/python/framework/load_library.py:151, in load_library(library_location)
#     148     kernel_libraries = [library_location]
#     150   for lib in kernel_libraries:
# --> 151     py_tf.TF_LoadLibrary(lib)
#     153 else:
#     154   raise OSError(
#     155       errno.ENOENT,
#     156       'The file or folder to load kernel libraries from does not exist.',
#     157       library_location)
#
# NotFoundError: dlopen(/Users/All file hear/complete ai /Deep learning/.venv/lib/python3.12/site-packages/tensorflow-plugins/libmetal_plugin.dylib, 0x0006): Library not loaded: @rpath/_pywrap_tensorflow_internal.so
#   Referenced from: <8B62586B-B082-3113-93AB-FD766A9960AE> /Users/All file hear/complete ai /Deep learning/.venv/lib/python3.12/site-packages/tensorflow-plugins/libmetal_plugin.dylib
#   Reason: tried: '/Users/All file hear/complete ai /Deep learning/.venv/lib/python3.12/site-packages/tensorflow-plugins/../_solib_darwin_arm64/_U@local_Uconfig_Utf_S_S_C_Upywrap_Utensorflow_Uinternal___Uexternal_Slocal_Uconfig_Utf/_pywrap_tensorflow_internal.so' (no such file), '/Users/All file hear/complete ai /Deep learning/.venv/lib/python3.12/site-packages/tensorflow-plugins/../_solib_darwin_arm64/_U@local_Uconfig_Utf_S_S_C_Upywrap_Utensorflow_Uinternal___Uexternal_Slocal_Uconfig_Utf/_pywrap_tensorflow_internal.so' (no such file), '/Users/mohit/.local/share/uv/python/cpython-3.12.12-macos-aarch64-none/lib/_pywrap_tensorflow_internal.so' (no such file)

# %%
import tensorflow as tf
import keras
import sys


print("Python:", sys.version)
print("TensorFlow:", tf.__version__)
print("Keras:", keras.__version__)
print("Python executable:", sys.executable)
# Out:
# Python: 3.13.9 | packaged by Anaconda, Inc. | (main, Oct 21 2025, 19:11:29) [Clang 20.1.8 ]
# TensorFlow: 2.21.0
# Keras: 3.15.0
# Python executable: /Users/All file hear/complete ai /Deep learning/.venv/bin/python

# %%
import platform
import sys

print(platform.python_version())
print(sys.executable)
# Out:
# 3.12.12
# /Users/All file hear/complete ai /Deep learning/.venv/bin/python
